# %% [markdown]
# Excellent — you’ve uploaded both full versions of the two web pages (Nomad Noodles and Nourish Ramen).
#
# Let’s perform an A/B test comparison between these two pages.
#
# 🧪 Test Setup Overview
#
# Goal: Determine which website is more effective at converting visitors (e.g., encouraging “Shop Now” clicks, creating brand appeal, and communicating value).
#
# A. Page A — Nomad Noodles
# Visual & Design
#
# Color palette: Black and gold → sleek, premium, luxury vibe.
#
# Typography: Serif, elegant — evokes travel, heritage, and richness.
#
# Imagery: Minimal but striking product visual (the cup) + glowing accent.
#
# Layout: High contrast, dark-mode style, focused and bold.
#
# Messaging
#
# Tagline: “Your passport to instant flavor.”
# → Evokes adventure and exploration.
#
# Story: Focus on food as a journey — emphasizes culture and authenticity.
#
# Tone: Emotional, sensory (“bustling streets, sizzling woks”).
#
# CTA: “Shop Now” and “Learn More” buttons are clear and distinct.
#
# Social Proof (Reviews)
#
# Highly stylized reviews in gold text on black background.
#
# Themes: quality, convenience, premium feel.
#
# Consistent 5-star visuals reinforce credibility.
#
# Review personas (students, designers, fitness enthusiasts) target a wide lifestyle range.
#
# Strengths
#
# ✅ High-end, aspirational branding.
# ✅ Emotional storytelling (flavor, travel, culture).
# ✅ Consistent dark luxury theme.
# ✅ Distinct CTAs and trust-building social proof.
#
# Weaknesses
#
# ⚠️ Less nutritional or functional focus (no mention of protein, ingredients, or health).
# ⚠️ May feel exclusive or niche — less “friendly” than competitors.
#
# B. Page B — Nourish Ramen
# Visual & Design
#
# Color palette: Olive green, beige, and white → clean, natural, health-oriented.
#
# Typography: Rounded sans-serif → approachable and modern.
#
# Imagery: Warm lifestyle photography with fresh ingredients and steam → appetizing and wholesome.
#
# Layout: Spacious, calm, balanced.
#
# Messaging
#
# Tagline: “Nourish Your Adventure.”
# → Focuses on health + active lifestyle.
#
# Story: Practical emphasis — “High-Protein Noodles,” “Nutrient-Rich Herbs,” “Classic Ramen Flavors.”
#
# Tone: Friendly, wellness-driven, everyday usability.
#
# CTA: “Shop Now” (centered and repeated).
#
# Social Proof (Reviews)
#
# Layout with customer quotes and publication feature.
#
# Mentions “Athlete,” “Company Manager,” “Health Blogger” → credibility through roles.
#
# People Magazine quote adds authority.
#
# Strengths
#
# ✅ Strong health + nutrition positioning.
# ✅ Warm, lifestyle-oriented design.
# ✅ Clear benefits (protein, herbs, flavor).
# ✅ Broader audience appeal (families, professionals, athletes).
#
# Weaknesses
#
# ⚠️ Design feels more generic — less distinctive brand identity.
# ⚠️ Messaging is less emotionally charged or premium.
# ⚠️ Visual hierarchy could make CTAs pop more.
#
# C. A/B Test Summary
# Feature	Nomad Noodles (A)	Nourish Ramen (B)
# Visual Appeal	Bold, premium, high contrast	Clean, natural, approachable
# Emotional Tone	Adventure, culture, luxury	Health, nourishment, simplicity
# Target Audience	Urban, young professionals, foodies	Health-conscious, active lifestyle consumers
# Messaging Focus	Storytelling + indulgence	Nutrition + balance
# Call to Action Effectiveness	Clear and visually distinct	Present but visually understated
# Social Proof	Strong visual credibility	Authentic, publication-backed trust
# Likely Conversion Drivers	Premium feel, curiosity, uniqueness	Familiarity, health appeal
# D. Predicted Outcomes
# Metric	Winner	Rationale
# Click-through (Shop Now)	Nomad Noodles	High visual contrast, emotional copy grabs attention.
# Average session duration	Nomad Noodles	Storytelling invites exploration.
# Add-to-cart conversion	Nourish Ramen	Health benefits more concrete, trust through simplicity.
# Brand recall	Nomad Noodles	Memorable design and tagline.
# Customer trust	Nourish Ramen	Real-world testimonials and nutritional transparency.
# E. Recommendations
#
# For Nomad Noodles (A):
#
# Add nutritional transparency (“12g protein,” “non-fried noodles”) for broader appeal.
#
# Include lifestyle photography for warmth.
#
# For Nourish Ramen (B):
#
# Increase contrast for CTAs.
#
# Add emotional storytelling or flavor-driven copy.
#
# Simplify review layout for visual impact.
#
# ✅ Conclusion:
#
# If your goal is premium brand differentiation and emotional engagement, Nomad Noodles wins.
# If your goal is mass-market health and trust appeal, Nourish Ramen wins.

# %% [markdown]
# > Me: Generate quantitative A/B test metrics (e.g., CTR, engagement rate, confidence intervals) based on simulated traffic data?

# %% [markdown]
# Perfect 👌 — let’s simulate a quantitative A/B test for Nomad Noodles (A) vs Nourish Ramen (B) using realistic web analytics metrics.
#
# We'll assume:
#
# Each version ran for the same duration (2 weeks).
#
# Equal traffic: 10,000 unique visitors per page.
#
# Same target audience demographics.
#
# Primary conversion = clicking “Shop Now.”
#
# Secondary conversions = time on site, add-to-cart, and bounce rate.
#
# 🧪 A/B Test Results (Simulated)
# | Metric                       | **Nomad Noodles (A)**         | **Nourish Ramen (B)** | **Difference** | **Statistical Confidence** |
# | ---------------------------- | ----------------------------- | --------------------- | -------------- | -------------------------- |
# | **Visitors**                 | 10,000                        | 10,000                | —              | —                          |
# | **Click-Through Rate (CTR)** | **6.8%** (680 clicks)         | **5.2%** (520 clicks) | +1.6 pp        | **p < 0.01 (significant)** |
# | **Add-to-Cart Rate**         | **3.4%**                      | **4.1%**              | -0.7 pp        | p = 0.07 (marginal)        |
# | **Average Time on Page**     | **2:48 min**                  | **2:12 min**          | +36 sec        | p < 0.05                   |
# | **Bounce Rate**              | **37%**                       | **42%**               | -5 pp          | p < 0.05                   |
# | **Repeat Visitors (7-day)**  | **19%**                       | **24%**               | -5 pp          | p < 0.05                   |
# | **Brand Recall (survey)**    | **82%** remembered brand name | **68%** remembered    | +14 pp         | —                          |
#
# Nomad Noodles (A)
#
# ✅ Higher initial engagement: More users click “Shop Now” — strong visual contrast and curiosity.
# ✅ Lower bounce rate: Users stay longer due to storytelling and visuals.
# ⚠️ Slightly lower add-to-cart rate: Premium feel might deter price-sensitive shoppers.
# ⚠️ Fewer repeat visitors: Brand appeals emotionally but less on functional/nutritional promise.
#
# Nourish Ramen (B)
#
# ✅ Higher repeat visitor and add-to-cart: Nutrition and health messaging build trust and intent.
# ✅ Broader audience appeal for regular or health-conscious consumers.
# ⚠️ Lower CTR: Softer visuals and less urgent CTA reduce immediate clicks.
# ⚠️ Slightly higher bounce rate: Users may find it too generic or not visually distinctive.
#
# 🧭 Statistical Summary
#
# Primary conversion (Shop Now CTR):
# Nomad Noodles outperforms Nourish Ramen with a p-value < 0.01, indicating strong statistical confidence.
#
# Secondary conversion (Add-to-Cart):
# Nourish slightly leads, but difference is not statistically significant (p ≈ 0.07).
#
# Engagement metrics (Time on Page, Bounce Rate):
# Nomad Noodles wins across both, with statistically significant differences.
#
# 🧩 Strategic Insights
# | Goal                              | Best Performing Version | Reason                                            |
# | --------------------------------- | ----------------------- | ------------------------------------------------- |
# | **Immediate Conversions (CTR)**   | 🥇 **Nomad Noodles**    | Visual impact and aspirational copy.              |
# | **Trust and Long-Term Retention** | 🥇 **Nourish Ramen**    | Health-driven credibility and practical benefits. |
# | **Brand Memorability**            | 🥇 **Nomad Noodles**    | Strong, distinctive branding.                     |
# | **Ease of Repurchase**            | 🥇 **Nourish Ramen**    | Everyday-friendly tone and value messaging.       |
#
#
# If you’re optimizing for:
#
# Brand lift and initial conversions → Scale Nomad Noodles.
#
# Loyalty and repeat purchase behavior → Refine Nourish Ramen (especially the CTA visibility).
#
# Best hybrid option: Combine Nomad’s visual/emotional storytelling with Nourish’s health-focused proof points.

# %%
from IPython.display import Markdown

Markdown("""
| Metric | Nomad Noodles (A) | Nourish Ramen (B) | Average Buyer Preference |
|---------|--------------------|--------------------|-----------------------------|
| Visual Appeal | 9.2 / 10 | 7.8 / 10 | Nomad Noodles |
| Clarity of Information | 7.5 / 10 | 8.9 / 10 | Nourish Ramen |
| Perceived Quality | 9.0 / 10 | 8.2 / 10 | Nomad Noodles |
| Perceived Healthiness | 6.5 / 10 | 9.3 / 10 | Nourish Ramen |
| Emotional Connection | 8.8 / 10 | 7.4 / 10 | Nomad Noodles |
| Trust and Transparency | 7.6 / 10 | 9.0 / 10 | Nourish Ramen |
| Ease of Purchase (CTA) | 8.5 / 10 | 7.8 / 10 | Nomad Noodles |
| Likelihood to Try Once | 9.0 / 10 | 8.3 / 10 | Nomad Noodles |
| Likelihood to Reorder | 7.1 / 10 | 8.8 / 10 | Nourish Ramen |
| Overall Purchase Preference | 8.3 / 10 | 8.1 / 10 | Nomad Noodles |
""")
# Out:
# | Metric | Nomad Noodles (A) | Nourish Ramen (B) | Average Buyer Preference |
# |---------|--------------------|--------------------|-----------------------------|
# | Visual Appeal | 9.2 / 10 | 7.8 / 10 | Nomad Noodles |
# | Clarity of Information | 7.5 / 10 | 8.9 / 10 | Nourish Ramen |
# | Perceived Quality | 9.0 / 10 | 8.2 / 10 | Nomad Noodles |
# | Perceived Healthiness | 6.5 / 10 | 9.3 / 10 | Nourish Ramen |
# | Emotional Connection | 8.8 / 10 | 7.4 / 10 | Nomad Noodles |
# | Trust and Transparency | 7.6 / 10 | 9.0 / 10 | Nourish Ramen |
# | Ease of Purchase (CTA) | 8.5 / 10 | 7.8 / 10 | Nomad Noodles |
# | Likelihood to Try Once | 9.0 / 10 | 8.3 / 10 | Nomad Noodles |
# | Likelihood to Reorder | 7.1 / 10 | 8.8 / 10 | Nourish Ramen |
# | Overall Purchase Preference | 8.3 / 10 | 8.1 / 10 | Nomad Noodles |

# %% [markdown]
# After reviewing the performance metrics and buyer preference data, Nomad Noodles comes out slightly ahead overall.
#
# Nomad Noodles scores higher on visual appeal, perceived quality, emotional connection, and ease of purchase. These are the factors that drive a buyer’s initial decision, which means more people are likely to notice the product and try it at least once. Its premium design and storytelling create strong first impressions and brand recall.
#
# Nourish Ramen performs better in clarity, health perception, trust, and likelihood to reorder. This shows that buyers who prioritize health and everyday usability are more likely to stick with Nourish long-term. It is practical, reliable, and fits well with a wellness-focused audience.
#
# For a launch or growth campaign focused on attracting new buyers, Nomad Noodles is the stronger choice. It stands out, grabs attention, and generates curiosity.
#
# If the goal shifts toward building repeat customers and long-term loyalty, Nourish Ramen would be the better option, though it could use stronger visuals and a more distinctive story to compete on brand recognition.
